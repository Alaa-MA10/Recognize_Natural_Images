# %% [markdown]
# # Imports

# %%
# !pip install tensorflow==1.15.3
# !pip install q Keras==2.2.5

# %%
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive
from random import shuffle
from tqdm import tqdm
from sklearn.model_selection import train_test_split

import tensorflow.contrib.keras as keras
from keras.models import Model, load_model
from keras.callbacks import TensorBoard,ModelCheckpoint
from keras.utils import to_categorical
from keras.layers import Input, GlobalMaxPooling2D, Dense, Dropout
from keras.optimizers import Adam

from datetime import datetime
import cv2
import tensorflow as tf

import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv 

tf.logging.set_verbosity(tf.logging.ERROR)

# %% [markdown]
# # Configurations

# %% [markdown]
# ## Mount Drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Constants

# %%
IMG_SIZE = 150
PROJECT_DIR = '/content/drive/MyDrive/Neural_Project/'
os.chdir(PROJECT_DIR)

DATA_PATH = os.path.join("Data (npy)")
date_time = datetime.now().strftime("(%Y/%m/%d, %H:%M)")

MODEL_NAME = "Inception-ResNet_V2"
EPOCHS_NUM = 10
log_dir = f"logs/{MODEL_NAME}({EPOCHS_NUM})-{date_time}"

train_image_path = os.path.join(DATA_PATH, 'train_image - (150-RGB).npy')
test_image_path = os.path.join(DATA_PATH, 'test_image - (150-RGB).npy')

MODEL_FOLDER = 'Inception_ResNet_V2'
#MODEL_PATH = os.path.join('Models', f'{MODEL_FOLDER}',f'{MODEL_NAME}_{date_time}_({EPOCHS_NUM}_epoch).model')

# %% [markdown]
# # Prepare Data

# %% [markdown]
# ## Create Train Data

# %%
def create_train_data():
  train_image = []

  for c in Classes['Image']:
    path = os.path.join('Scenes_training_set',c)   # path to building,forest,... folders , c = building,forest,..
    class_label = list(Classes['Image']).index(c)     # class_label = 0, 1, 2, 3, 4

    for img in tqdm(os.listdir(path)):
      img_data = cv2.imread(os.path.join(path,img), cv2.IMREAD_COLOR)
      img_data = cv2.cvtColor(img_data, cv2.COLOR_BGR2RGB)                  # Make it RGB 
      img_data = cv2.resize(img_data, (IMG_SIZE, IMG_SIZE))   # resize image

      train_image.append([np.array(img_data),class_label])

  shuffle(train_image)
  np.save(train_image_path, train_image)

  return train_image

# %% [markdown]
# ## Create Test Data

# %%
def create_test_data():
  test_image = []
  path = os.path.join('Scenes_testing_set')   # path to testing folder

  for img in tqdm(os.listdir(path)):
    img_data = cv2.imread(os.path.join(path,img), cv2.IMREAD_COLOR)
    img_data = cv2.cvtColor(img_data, cv2.COLOR_BGR2RGB)                  # Make it RGB 
    img_data = cv2.resize(img_data, (IMG_SIZE, IMG_SIZE))   # resize image
    
    test_image.append([np.array(img_data), img])

  np.save(test_image_path, test_image)

  return test_image

# %% [markdown]
# # MAIN

# %% [markdown]
# Reading CSV file

# %%
Classes = pd.read_csv('names.csv')

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Train dataset created OR not

# %%
# If Train dataset created or not
if (os.path.exists(train_image_path)):
  train_image = np.load(train_image_path, allow_pickle=True)
  print('Train dataset exist')
else:
  train_image = create_train_data()
# Out:
# Train dataset exist

# %% [markdown]
# ### Test dataset created OR not

# %%
# If Test dataset created or not
if (os.path.exists(test_image_path)):
  test_image = np.load(test_image_path, allow_pickle=True)
  print('Test dataset exist')
else:
  test_image = create_test_data()
# Out:
# Test dataset exist

# %% [markdown]
# ### Prepare X,Y

# %%
X = np.array([i[0] for i in train_image]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y = [i[1] for i in train_image]

# Normalization X 
X = X.astype('float32') / 255

# One Hot Encode Y
Y = to_categorical(Y)

# split train and validation
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.3, shuffle=True)

# %% [markdown]
# ## Train

# %% [markdown]
# ### Load Pre-train Model

# %% [markdown]
# 1. Load Pretrained Model with (imagenet) Pretrained weights

# %%
from inception_resnet_v2 import InceptionResNetV2

### Transfer learning and fine-tuning

# 1. Create the base model from the pre-trained weights
base_model = InceptionResNetV2(include_top=False, input_tensor=Input(X.shape[1:]), weights='imagenet')

# %% [markdown]
# 2. freeze all InceptionResNetV2 layers

# %%
#freeze all convolutional InceptionResNetV2 layers

for layer in base_model.layers:
  layer.trainable = False
  
print(len(base_model.layers))
# Out:
# 780

# %% [markdown]
# ### Define the Model

# %%
# Add new Layers on top

last_layer = base_model.output
x = GlobalMaxPooling2D()(last_layer)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x_output = Dense(6, activation='softmax')(x)

# %%
model = Model(inputs= base_model.input, outputs= x_output)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# Conv2d_1a_3x3 (Conv2D)          (None, 74, 74, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_BatchNorm (BatchN (None, 74, 74, 32)   96          Conv2d_1a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_Activation (Activ (None, 74, 74, 32)   0           Conv2d_1a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_2a_3x3 (Conv2D)          (None, 72, 72, 32)   9216        Conv2d_1a_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_2a_3x3_BatchNorm (BatchN (None, 72, 72, 32)   96          Conv2d_2a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_2a_3x3_Activation (Activ (None, 72, 72, 32)   0           Conv2d_2a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_2b_3x3 (Conv2D)          (None, 72, 72, 64)   18432       Conv2d_2a_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_2b_3x3_BatchNorm (BatchN (None, 72, 72, 64)   192         Conv2d_2b_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_2b_3x3_Activation (Activ (None, 72, 72, 64)   0           Conv2d_2b_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# MaxPool_3a_3x3 (MaxPooling2D)   (None, 35, 35, 64)   0           Conv2d_2b_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_3b_1x1 (Conv2D)          (None, 35, 35, 80)   5120        MaxPool_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_3b_1x1_BatchNorm (BatchN (None, 35, 35, 80)   240         Conv2d_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv2d_3b_1x1_Activation (Activ (None, 35, 35, 80)   0           Conv2d_3b_1x1_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_4a_3x3 (Conv2D)          (None, 33, 33, 192)  138240      Conv2d_3b_1x1_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_4a_3x3_BatchNorm (BatchN (None, 33, 33, 192)  576         Conv2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_4a_3x3_Activation (Activ (None, 33, 33, 192)  0           Conv2d_4a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# MaxPool_5a_3x3 (MaxPooling2D)   (None, 16, 16, 192)  0           Conv2d_4a_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0a_1x1 (None, 16, 16, 64)   12288       MaxPool_5a_3x3[0][0]
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0a_1x1 (None, 16, 16, 64)   192         Mixed_5b_Branch_2_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0a_1x1 (None, 16, 16, 64)   0           Mixed_5b_Branch_2_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Mixed_5b_Branch_1_Conv2d_0a_1x1 (None, 16, 16, 48)   9216        MaxPool_5a_3x3[0][0]
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0b_3x3 (None, 16, 16, 96)   55296       Mixed_5b_Branch_2_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Mixed_5b_Branch_1_Conv2d_0a_1x1 (None, 16, 16, 48)   144         Mixed_5b_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0b_3x3 (None, 16, 16, 96)   288         Mixed_5b_Branch_2_Conv2d_0b_3x3[0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_1_Conv2d_0a_1x1 (None, 16, 16, 48)   0           Mixed_5b_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0b_3x3 (None, 16, 16, 96)   0           Mixed_5b_Branch_2_Conv2d_0b_3x3_B
# __________________________________________________________________________________________________
# Mixed_5b_Branch_3_AvgPool_0a_3x (None, 16, 16, 192)  0           MaxPool_5a_3x3[0][0]
# __________________________________________________________________________________________________
# Mixed_5b_Branch_0_Conv2d_1x1 (C (None, 16, 16, 96)   18432       MaxPool_5a_3x3[0][0]
# __________________________________________________________________________________________________
# Mixed_5b_Branch_1_Conv2d_0b_5x5 (None, 16, 16, 64)   76800       Mixed_5b_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0c_3x3 (None, 16, 16, 96)   82944       Mixed_5b_Branch_2_Conv2d_0b_3x3_A
# __________________________________________________________________________________________________
# Mixed_5b_Branch_3_Conv2d_0b_1x1 (None, 16, 16, 64)   12288       Mixed_5b_Branch_3_AvgPool_0a_3x3[
# __________________________________________________________________________________________________
# Mixed_5b_Branch_0_Conv2d_1x1_Ba (None, 16, 16, 96)   288         Mixed_5b_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_1_Conv2d_0b_5x5 (None, 16, 16, 64)   192         Mixed_5b_Branch_1_Conv2d_0b_5x5[0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0c_3x3 (None, 16, 16, 96)   288         Mixed_5b_Branch_2_Conv2d_0c_3x3[0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_3_Conv2d_0b_1x1 (None, 16, 16, 64)   192         Mixed_5b_Branch_3_Conv2d_0b_1x1[0
# __________________________________________________________________________________________________
# Mixed_5b_Branch_0_Conv2d_1x1_Ac (None, 16, 16, 96)   0           Mixed_5b_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Mixed_5b_Branch_1_Conv2d_0b_5x5 (None, 16, 16, 64)   0           Mixed_5b_Branch_1_Conv2d_0b_5x5_B
# __________________________________________________________________________________________________
# Mixed_5b_Branch_2_Conv2d_0c_3x3 (None, 16, 16, 96)   0           Mixed_5b_Branch_2_Conv2d_0c_3x3_B
# __________________________________________________________________________________________________
# Mixed_5b_Branch_3_Conv2d_0b_1x1 (None, 16, 16, 64)   0           Mixed_5b_Branch_3_Conv2d_0b_1x1_B
# __________________________________________________________________________________________________
# Mixed_5b (Concatenate)          (None, 16, 16, 320)  0           Mixed_5b_Branch_0_Conv2d_1x1_Acti
#                                                                  Mixed_5b_Branch_1_Conv2d_0b_5x5_A
#                                                                  Mixed_5b_Branch_2_Conv2d_0c_3x3_A
#                                                                  Mixed_5b_Branch_3_Conv2d_0b_1x1_A
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_1_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_1_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_1_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_1_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_1_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_1_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_1_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_1_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_1_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_1_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_1_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_1_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_1_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_1_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_1_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_1_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_1_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_1_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_1_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_1_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_1_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_1_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_1_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_1_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_1_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Mixed_5b[0][0]
#                                                                  Block35_1_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_1_Activation (Activatio (None, 16, 16, 320)  0           Block35_1_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_2_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_2_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_2_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_2_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_2_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_2_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_2_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_2_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_2_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_2_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_2_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_2_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_2_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_2_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_2_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_2_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_2_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_2_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_2_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_2_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_2_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_2_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_2_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_2_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_2_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_1_Activation[0][0]
#                                                                  Block35_2_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_2_Activation (Activatio (None, 16, 16, 320)  0           Block35_2_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_3_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_3_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_3_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_3_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_3_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_3_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_3_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_3_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_3_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_3_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_3_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_3_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_3_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_3_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_3_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_3_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_3_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_3_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_3_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_3_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_3_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_3_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_3_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_3_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_3_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_2_Activation[0][0]
#                                                                  Block35_3_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_3_Activation (Activatio (None, 16, 16, 320)  0           Block35_3_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_4_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_4_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_4_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_4_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_4_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_4_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_4_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_4_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_4_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_4_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_4_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_4_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_4_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_4_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_4_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_4_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_4_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_4_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_4_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_4_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_4_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_4_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_4_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_4_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_4_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_3_Activation[0][0]
#                                                                  Block35_4_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_4_Activation (Activatio (None, 16, 16, 320)  0           Block35_4_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_5_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_5_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_5_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_5_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_5_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_5_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_5_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_5_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_5_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_5_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_5_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_5_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_5_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_5_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_5_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_5_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_5_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_5_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_5_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_5_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_5_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_5_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_5_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_5_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_5_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_4_Activation[0][0]
#                                                                  Block35_5_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_5_Activation (Activatio (None, 16, 16, 320)  0           Block35_5_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_5_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_6_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_6_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_6_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_5_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_6_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_6_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_6_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_6_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_6_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_6_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_6_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_6_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_5_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_6_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_6_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_6_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_6_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_6_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_6_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_6_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_6_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_6_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_6_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_6_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_6_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_6_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_6_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_6_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_6_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_6_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_6_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_6_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_6_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_6_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_5_Activation[0][0]
#                                                                  Block35_6_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_6_Activation (Activatio (None, 16, 16, 320)  0           Block35_6_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_6_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_7_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_7_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_7_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_6_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_7_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_7_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_7_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_7_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_7_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_7_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_7_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_7_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_6_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_7_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_7_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_7_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_7_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_7_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_7_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_7_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_7_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_7_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_7_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_7_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_7_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_7_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_7_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_7_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_7_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_7_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_7_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_7_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_7_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_7_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_6_Activation[0][0]
#                                                                  Block35_7_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_7_Activation (Activatio (None, 16, 16, 320)  0           Block35_7_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_7_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_8_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_8_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_8_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_7_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_8_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_8_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_8_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_8_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_8_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_8_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_8_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_8_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_7_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_8_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   9216        Block35_8_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   27648       Block35_8_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_8_Branch_0_Conv2d_1x1_B (None, 16, 16, 32)   96          Block35_8_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_8_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   96          Block35_8_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   192         Block35_8_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_8_Branch_0_Conv2d_1x1_A (None, 16, 16, 32)   0           Block35_8_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_8_Branch_1_Conv2d_0b_3x (None, 16, 16, 32)   0           Block35_8_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_8_Branch_2_Conv2d_0c_3x (None, 16, 16, 64)   0           Block35_8_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_8_Concatenate (Concaten (None, 16, 16, 128)  0           Block35_8_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_8_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_8_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_8_Conv2d_1x1 (Conv2D)   (None, 16, 16, 320)  41280       Block35_8_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block35_8_ScaleSum (Lambda)     (None, 16, 16, 320)  0           Block35_7_Activation[0][0]
#                                                                  Block35_8_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block35_8_Activation (Activatio (None, 16, 16, 320)  0           Block35_8_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block35_9_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_8_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_9_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_9_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_9_Branch_2_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_9_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_9_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   10240       Block35_8_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_9_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   13824       Block35_9_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_9_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   96          Block35_9_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_9_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   144         Block35_9_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_9_Branch_1_Conv2d_0a_1x (None, 16, 16, 32)   0           Block35_9_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_9_Branch_2_Conv2d_0b_3x (None, 16, 16, 48)   0           Block35_9_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_9_Branch_0_Conv2d_1x1 ( (None, 16, 16, 32)   10240       Block35_8_Activation[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# Block8_6_Concatenate (Concatena (None, 3, 3, 448)    0           Block8_6_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_6_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_6_Conv2d_1x1 (Conv2D)    (None, 3, 3, 2080)   933920      Block8_6_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block8_6_ScaleSum (Lambda)      (None, 3, 3, 2080)   0           Block8_5_Activation[0][0]
#                                                                  Block8_6_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block8_6_Activation (Activation (None, 3, 3, 2080)   0           Block8_6_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    399360      Block8_6_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_7_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_7_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    129024      Block8_7_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    672         Block8_7_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    0           Block8_7_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_7_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    399360      Block8_6_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    172032      Block8_7_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_7_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_7_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    768         Block8_7_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_7_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_7_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_7_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    0           Block8_7_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_7_Concatenate (Concatena (None, 3, 3, 448)    0           Block8_7_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_7_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_7_Conv2d_1x1 (Conv2D)    (None, 3, 3, 2080)   933920      Block8_7_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block8_7_ScaleSum (Lambda)      (None, 3, 3, 2080)   0           Block8_6_Activation[0][0]
#                                                                  Block8_7_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block8_7_Activation (Activation (None, 3, 3, 2080)   0           Block8_7_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    399360      Block8_7_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_8_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_8_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    129024      Block8_8_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    672         Block8_8_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    0           Block8_8_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_8_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    399360      Block8_7_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    172032      Block8_8_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_8_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_8_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    768         Block8_8_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_8_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_8_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_8_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    0           Block8_8_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_8_Concatenate (Concatena (None, 3, 3, 448)    0           Block8_8_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_8_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_8_Conv2d_1x1 (Conv2D)    (None, 3, 3, 2080)   933920      Block8_8_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block8_8_ScaleSum (Lambda)      (None, 3, 3, 2080)   0           Block8_7_Activation[0][0]
#                                                                  Block8_8_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block8_8_Activation (Activation (None, 3, 3, 2080)   0           Block8_8_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    399360      Block8_8_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_9_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_9_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    129024      Block8_9_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    672         Block8_9_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 224)    0           Block8_9_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_9_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    399360      Block8_8_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    172032      Block8_9_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_9_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_9_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    768         Block8_9_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_9_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_9_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_9_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 256)    0           Block8_9_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_9_Concatenate (Concatena (None, 3, 3, 448)    0           Block8_9_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_9_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_9_Conv2d_1x1 (Conv2D)    (None, 3, 3, 2080)   933920      Block8_9_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block8_9_ScaleSum (Lambda)      (None, 3, 3, 2080)   0           Block8_8_Activation[0][0]
#                                                                  Block8_9_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Block8_9_Activation (Activation (None, 3, 3, 2080)   0           Block8_9_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0a_1x (None, 3, 3, 192)    399360      Block8_9_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0a_1x (None, 3, 3, 192)    576         Block8_10_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0a_1x (None, 3, 3, 192)    0           Block8_10_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0b_1x (None, 3, 3, 224)    129024      Block8_10_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0b_1x (None, 3, 3, 224)    672         Block8_10_Branch_1_Conv2d_0b_1x3[
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0b_1x (None, 3, 3, 224)    0           Block8_10_Branch_1_Conv2d_0b_1x3_
# __________________________________________________________________________________________________
# Block8_10_Branch_0_Conv2d_1x1 ( (None, 3, 3, 192)    399360      Block8_9_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0c_3x (None, 3, 3, 256)    172032      Block8_10_Branch_1_Conv2d_0b_1x3_
# __________________________________________________________________________________________________
# Block8_10_Branch_0_Conv2d_1x1_B (None, 3, 3, 192)    576         Block8_10_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0c_3x (None, 3, 3, 256)    768         Block8_10_Branch_1_Conv2d_0c_3x1[
# __________________________________________________________________________________________________
# Block8_10_Branch_0_Conv2d_1x1_A (None, 3, 3, 192)    0           Block8_10_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block8_10_Branch_1_Conv2d_0c_3x (None, 3, 3, 256)    0           Block8_10_Branch_1_Conv2d_0c_3x1_
# __________________________________________________________________________________________________
# Block8_10_Concatenate (Concaten (None, 3, 3, 448)    0           Block8_10_Branch_0_Conv2d_1x1_Act
#                                                                  Block8_10_Branch_1_Conv2d_0c_3x1_
# __________________________________________________________________________________________________
# Block8_10_Conv2d_1x1 (Conv2D)   (None, 3, 3, 2080)   933920      Block8_10_Concatenate[0][0]
# __________________________________________________________________________________________________
# Block8_10_ScaleSum (Lambda)     (None, 3, 3, 2080)   0           Block8_9_Activation[0][0]
#                                                                  Block8_10_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# Conv2d_7b_1x1 (Conv2D)          (None, 3, 3, 1536)   3194880     Block8_10_ScaleSum[0][0]
# __________________________________________________________________________________________________
# Conv2d_7b_1x1_BatchNorm (BatchN (None, 3, 3, 1536)   4608        Conv2d_7b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv2d_7b_1x1_Activation (Activ (None, 3, 3, 1536)   0           Conv2d_7b_1x1_BatchNorm[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 1536)         0           Conv2d_7b_1x1_Activation[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          786944      global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            3078        dropout_1[0][0]
# ==================================================================================================
# Total params: 55,126,758
# Trainable params: 790,022
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training

# %%
# Compile the model 
model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# checkpoint for pre-train model
pretrain_checkpoint_path = os.path.join('Models', f'{MODEL_FOLDER}','Pre-train_Inception-ResNetV2_epoch:{epoch:02d}_acc:{val_acc:.4f}.h5')
pretrain_checkpoint = ModelCheckpoint(pretrain_checkpoint_path, monitor= 'val_acc', mode= 'max', save_best_only= True, verbose=1)

# %%
# Train the model
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_val, Y_val), callbacks=[pretrain_checkpoint])
